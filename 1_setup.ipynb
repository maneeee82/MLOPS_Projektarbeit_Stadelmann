# %%
# Install Hopsworks Python client
#!pip install "hopsworks[python]"

# Connect to Hopsworks
import hopsworks

project = hopsworks.login(
    project='MLOPS_PA_Stadelmann',  # Replace with your project name
    host="eu-west.cloud.hopsworks.ai",
    port=443,
    api_key_value="dEy9kOrkpFrzFfJ4.p83i3p8YcCxOUm2SZGoDcYIIeaCCnFaKX6IfzuLVzDRJSBzXU6LJ2oPGZKZ6azSg"  # Get from Hopsworks UI > Account Settings > API Keys
)

# Access the feature store
fs = project.get_feature_store()

# # Example: Read an existing feature group
# fg = fs.get_feature_group(
#     name="your_feature_group",
#     version=1
# )

# # Read data from the feature group
# df = fg.read()
# print(f"Connected to {project.name}. Feature group has {len(df)} rows")

# For model serving
ms = project.get_model_serving()

# For model registry
mr = project.get_model_registry()
# Out:
# 2026-04-13 20:14:53,866 INFO: Closing external client and cleaning up certificates.
# 2026-04-13 20:14:53,867 INFO: Connection closed.
# 2026-04-13 20:14:53,868 INFO: Initializing external client
# 2026-04-13 20:14:53,868 INFO: Base URL: https://eu-west.cloud.hopsworks.ai:443
# 2026-04-13 20:14:54,959 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://eu-west.cloud.hopsworks.ai:443/p/31942
